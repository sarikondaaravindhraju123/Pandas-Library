# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92326725-7576-4947-8ade-8ef7ffb9ecfc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92326725-7576-4947-8ade-8ef7ffb9ecfc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("weather_data2.csv")
df
# Out:
#           day temperature windspeed     event
# 0  01/01/2017        32 F     6 mph      Rain
# 1  01/02/2017      -99999     7 mph     Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017        32 C    -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
# Replace -99999 with NaN values :

new_df = df.replace(-99999,np.NaN)
new_df
# Out:
#           day temperature windspeed     event
# 0  01/01/2017        32 F     6 mph      Rain
# 1  01/02/2017      -99999     7 mph     Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017        32 C    -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
 df
# Out:
#           day temperature windspeed     event
# 0  01/01/2017        32 F     6 mph      Rain
# 1  01/02/2017      -99999     7 mph     Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017        32 C    -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
new_df1 = df.replace({
    "temperature" : -99999,
    "windspeed" : -99999
},np.NaN)

new_df1
# Out:
#           day temperature windspeed     event
# 0  01/01/2017        32 F     6 mph      Rain
# 1  01/02/2017      -99999     7 mph     Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017        32 C    -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
new_df
# Out:
#           day temperature windspeed     event
# 0  01/01/2017        32 F     6 mph      Rain
# 1  01/02/2017      -99999     7 mph     Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017        32 C    -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
new_df = df.replace({
    -99999 : np.NaN,
    "No Event" : "Sunny"
})

new_df
# Out:
#           day temperature windspeed  event
# 0  01/01/2017        32 F     6 mph   Rain
# 1  01/02/2017      -99999     7 mph  Sunny
# 2  01/03/2017          28    -99999   Snow
# 3  01/04/2017      -99999         7  Sunny
# 4  01/05/2017        32 C    -99999   Rain
# 5  01/06/2017          31         2  Sunny
# 6  01/06/2017          34         5  Sunny

# %%
# Remove the units infornt of values:

new_df = df.replace("[A-Za-z]",'',regex=True)
new_df
# Out:
#           day temperature windspeed event
# 0  01/01/2017         32         6
# 1  01/02/2017      -99999        7
# 2  01/03/2017          28    -99999
# 3  01/04/2017      -99999         7
# 4  01/05/2017         32     -99999
# 5  01/06/2017          31         2
# 6  01/06/2017          34         5

# %%
# observe the above df the event column is empty because all values in that column are letters

# %%
# Lets change this using Dictionary :

new_df = df.replace({
    "temperature" : "[A-Za-z]",
    "windspeed" : "[A-Za-z]"
},'',regex=True)

new_df
# Out:
#           day temperature windspeed     event
# 0  01/01/2017         32         6       Rain
# 1  01/02/2017      -99999        7      Sunny
# 2  01/03/2017          28    -99999      Snow
# 3  01/04/2017      -99999         7  No Event
# 4  01/05/2017         32     -99999      Rain
# 5  01/06/2017          31         2     Sunny
# 6  01/06/2017          34         5  No Event

# %%
# Creating a DataFrame

df = pd.DataFrame({
    'Score' : ['exceptional','avg','good','poor','avg','exceptional'],
    'Student' : ['rob','maya','parthiv','tom','julian','erica']
})

df
# Out:
#          Score  Student
# 0  exceptional      rob
# 1          avg     maya
# 2         good  parthiv
# 3         poor      tom
# 4          avg   julian
# 5  exceptional    erica

# %%
# Replacing List of values with another list of values :

df.replace(["exceptional","good","avg","poor"],[1,2,3,4])
# Out:
#    Score  Student
# 0      1      rob
# 1      3     maya
# 2      2  parthiv
# 3      4      tom
# 4      3   julian
# 5      1    erica
