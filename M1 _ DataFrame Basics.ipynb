# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7aeb400-4968-4046-ac6f-f220e8560c04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7aeb400-4968-4046-ac6f-f220e8560c04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("weather (3).csv",sep = ',')

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#dimensions:

# %%
rows,columns = df.shape
rows
# Out:
# 3

# %%
columns
# Out:
# 4

# %%
# this prints top rows
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
# tail : It prints bottom rows
df.tail()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# slicing

# %%
df[0 :: 3]
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain

# %%
# print column names:
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
# print individual rows:
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# Name: event, dtype: object

# %%
# we can use in this way or above type:
df["temperature"]
# Out:
# 0    32
# 1    35
# 2    28
# Name: temperature, dtype: int64

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# print only event and day from df:
df[["day","event"]]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow

# %%
# what is the maximuum temp in dataframe:
df.temperature.max()
# Out:
# 35

# %%
# what is the minimum temp in dataframe:
df.temperature.min()
# Out:
# 28

# %%
# check weather there are any duplicate temp values in dataframe
df.temperature.is_unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-a411547274ad> in <cell line: 2>()
#       1 # check weather there are any duplicate temp values in dataframe
# ----> 2 df.temperature.is_unique()
#
# TypeError: 'bool' object is not callable

# %%
# print count of values in dataframe:
df.temperature.value_counts()
# Out:
# 32    1
# 35    1
# 28    1
# Name: temperature, dtype: int64

# %%
# print the mean of temperature in dataframe:
df.temperature.mean()
# Out:
# 31.666666666666668

# %%
# print the standard deviation of temperature in dataframe:
df.temperature.std()
# Out:
# 3.5118845842842465

# %%
# describe - This prints the statisrics of dataframe:
df.describe()
# Out:
#        temperature  windspeed
# count     3.000000   3.000000
# mean     31.666667   5.000000
# std       3.511885   2.645751
# min      28.000000   2.000000
# 25%      30.000000   4.000000
# 50%      32.000000   6.000000
# 75%      33.500000   6.500000
# max      35.000000   7.000000

# %%
# print the temperatures which are greater than or equal to 32
df.temperature >= 32
# Out:
# 0     True
# 1     True
# 2    False
# Name: temperature, dtype: bool

# %%
df[df.temperature >= 32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
# maximum temperature:
df[df.temperature == df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
# print day,temperature in dataframe which is maximum temperature
df[["day","temperature"]][df.temperature == df.temperature.max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# change day as your index
df.set_index("day")
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow

# %%
# observe the difference from above
# that doesn't reflect to original df
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow

# %%
# reset_index : it resets the column of a dataframe
df.reset_index("day")
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow

# %%
df.reset_index("day")
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# now get any temp using day as index:
# .loc function is only used with indexing
df.loc["1/2/2017"]
# Out:
# temperature       35
# windspeed          7
# event          Sunny
# Name: 1/2/2017, dtype: object

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow

# %%
df.reset_index(inplace =True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.set_index("day",inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
